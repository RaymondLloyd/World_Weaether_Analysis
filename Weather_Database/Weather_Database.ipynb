# %%
# %load_ext autoreload

# %autoreload

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.00, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_country = city_weather["sys"]["country"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bad liebenwerda
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | walvis bay
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | mabaruma
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | laguna
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | duz
# City not found. Skipping...
# Processing Record 23 of Set 1 | bilibino
# Processing Record 24 of Set 1 | baykit
# Processing Record 25 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | acandi
# Processing Record 28 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 1 | ulaangom
# Processing Record 30 of Set 1 | karratha
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | finschhafen
# Processing Record 34 of Set 1 | muros
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | sokoni
# Processing Record 39 of Set 1 | saint stephen
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | san cristobal
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | cap-aux-meules
# Processing Record 46 of Set 1 | fairbanks
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | acapulco
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | hualmay
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | alihe
# Processing Record 4 of Set 2 | george town
# Processing Record 5 of Set 2 | tuy hoa
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 2 | tessalit
# Processing Record 9 of Set 2 | vila do maio
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | kendari
# Processing Record 16 of Set 2 | durango
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | arica
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | panji
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | yar-sale
# Processing Record 28 of Set 2 | chimore
# Processing Record 29 of Set 2 | auki
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | montepuez
# Processing Record 32 of Set 2 | barsovo
# Processing Record 33 of Set 2 | teyateyaneng
# Processing Record 34 of Set 2 | bay roberts
# Processing Record 35 of Set 2 | lasa
# Processing Record 36 of Set 2 | ambilobe
# Processing Record 37 of Set 2 | sao jose da coroa grande
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | brindisi
# Processing Record 40 of Set 2 | malpe
# Processing Record 41 of Set 2 | pacific grove
# Processing Record 42 of Set 2 | marawi
# Processing Record 43 of Set 2 | port macquarie
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | sept-iles
# Processing Record 46 of Set 2 | katobu
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | san policarpo
# Processing Record 50 of Set 2 | el uvito
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | alim
# Processing Record 3 of Set 3 | pokhara
# Processing Record 4 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 3 | artur nogueira
# Processing Record 6 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 3 | okato
# Processing Record 8 of Set 3 | solnechnyy
# Processing Record 9 of Set 3 | bambari
# Processing Record 10 of Set 3 | kavaratti
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | zhigansk
# Processing Record 13 of Set 3 | harper
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | collie
# Processing Record 16 of Set 3 | kodinsk
# Processing Record 17 of Set 3 | borgarnes
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | savalou
# Processing Record 20 of Set 3 | cuamba
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | kaifeng
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 3 | lompoc
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | duldurga
# Processing Record 33 of Set 3 | alexandria
# Processing Record 34 of Set 3 | ola
# Processing Record 35 of Set 3 | bonthe
# Processing Record 36 of Set 3 | durres
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | raymondville
# Processing Record 39 of Set 3 | kahului
# Processing Record 40 of Set 3 | rumonge
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | hanzhong
# Processing Record 43 of Set 3 | tvoroyri
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | aykhal
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | samarai
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | vao
# Processing Record 1 of Set 4 | libreville
# Processing Record 2 of Set 4 | nicoya
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | bongandanga
# Processing Record 5 of Set 4 | komsomolskiy
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | vila franca do campo
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | rudiskes
# Processing Record 10 of Set 4 | omsukchan
# Processing Record 11 of Set 4 | quincy
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | tsurugashima
# Processing Record 14 of Set 4 | kontagora
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | nagato
# Processing Record 19 of Set 4 | nieuw amsterdam
# Processing Record 20 of Set 4 | cabra
# Processing Record 21 of Set 4 | shunyi
# Processing Record 22 of Set 4 | mitsamiouli
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | aksu
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 4 | krasnoarmeysk
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | huarmey
# Processing Record 32 of Set 4 | balkhash
# Processing Record 33 of Set 4 | vallenar
# Processing Record 34 of Set 4 | dikson
# Processing Record 35 of Set 4 | matara
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | berlevag
# Processing Record 38 of Set 4 | ahipara
# Processing Record 39 of Set 4 | goderich
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | katangli
# Processing Record 42 of Set 4 | henties bay
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | orlik
# Processing Record 45 of Set 4 | avarua
# Processing Record 46 of Set 4 | eqbaliyeh
# Processing Record 47 of Set 4 | kudat
# Processing Record 48 of Set 4 | matir
# City not found. Skipping...
# Processing Record 49 of Set 4 | evensk
# Processing Record 50 of Set 4 | flagstaff
# Processing Record 1 of Set 5 | birao
# Processing Record 2 of Set 5 | porto de moz
# Processing Record 3 of Set 5 | lerwick
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | szczecinek
# Processing Record 6 of Set 5 | poya
# Processing Record 7 of Set 5 | maniitsoq
# Processing Record 8 of Set 5 | yatou
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | savannah bight
# Processing Record 11 of Set 5 | guerrero negro
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | chaah
# Processing Record 15 of Set 5 | budhgaon
# City not found. Skipping...
# Processing Record 16 of Set 5 | wadi maliz
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | challapata
# Processing Record 19 of Set 5 | asau
# Processing Record 20 of Set 5 | saint-francois
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | pampas
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | denpasar
# Processing Record 25 of Set 5 | gawler
# Processing Record 26 of Set 5 | americus
# Processing Record 27 of Set 5 | cave spring
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | lorengau
# Processing Record 30 of Set 5 | llangefni
# Processing Record 31 of Set 5 | anaconda
# Processing Record 32 of Set 5 | wellington
# Processing Record 33 of Set 5 | taltal
# Processing Record 34 of Set 5 | namatanai
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | burnie
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | puerto leguizamo
# Processing Record 40 of Set 5 | nuuk
# Processing Record 41 of Set 5 | thaton
# Processing Record 42 of Set 5 | avera
# Processing Record 43 of Set 5 | sabha
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | oriximina
# Processing Record 46 of Set 5 | tuktoyaktuk
# Processing Record 47 of Set 5 | nipawin
# Processing Record 48 of Set 5 | uroteppa
# City not found. Skipping...
# Processing Record 49 of Set 5 | metabetchouan
# City not found. Skipping...
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | grand gaube
# Processing Record 2 of Set 6 | tir pol
# City not found. Skipping...
# Processing Record 3 of Set 6 | gizo
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | honiara
# Processing Record 6 of Set 6 | lagoa
# Processing Record 7 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 6 | penukonda
# Processing Record 11 of Set 6 | alofi
# Processing Record 12 of Set 6 | sumbe
# Processing Record 13 of Set 6 | morki
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | nizza monferrato
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 6 | aguimes
# Processing Record 18 of Set 6 | opuwo
# Processing Record 19 of Set 6 | hit
# Processing Record 20 of Set 6 | kagadi
# Processing Record 21 of Set 6 | tari
# Processing Record 22 of Set 6 | akdepe
# Processing Record 23 of Set 6 | barra do garcas
# Processing Record 24 of Set 6 | rapina
# Processing Record 25 of Set 6 | necochea
# Processing Record 26 of Set 6 | mehamn
# Processing Record 27 of Set 6 | lucapa
# Processing Record 28 of Set 6 | at-bashi
# Processing Record 29 of Set 6 | awbari
# Processing Record 30 of Set 6 | inongo
# Processing Record 31 of Set 6 | chernyshevskiy
# Processing Record 32 of Set 6 | kaspi
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | moerai
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | luwuk
# Processing Record 38 of Set 6 | garowe
# Processing Record 39 of Set 6 | jieshi
# Processing Record 40 of Set 6 | teya
# Processing Record 41 of Set 6 | nador
# Processing Record 42 of Set 6 | cayenne
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | corner brook
# Processing Record 45 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 6 | rochegda
# Processing Record 47 of Set 6 | tripoli
# Processing Record 48 of Set 6 | nouadhibou
# Processing Record 49 of Set 6 | hervey bay
# Processing Record 50 of Set 6 | nantucket
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | abu dhabi
# Processing Record 3 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 7 | quelimane
# Processing Record 5 of Set 7 | mangrol
# Processing Record 6 of Set 7 | isangel
# Processing Record 7 of Set 7 | vilhena
# Processing Record 8 of Set 7 | maimon
# City not found. Skipping...
# Processing Record 9 of Set 7 | valparaiso
# Processing Record 10 of Set 7 | montefiascone
# Processing Record 11 of Set 7 | bilecik
# Processing Record 12 of Set 7 | lubango
# Processing Record 13 of Set 7 | luderitz
# Processing Record 14 of Set 7 | huaibei
# Processing Record 15 of Set 7 | gurupa
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | baghdad
# Processing Record 18 of Set 7 | tam ky
# Processing Record 19 of Set 7 | torbay
# Processing Record 20 of Set 7 | burica
# City not found. Skipping...
# Processing Record 21 of Set 7 | bilma
# Processing Record 22 of Set 7 | krasnoselkup
# Processing Record 23 of Set 7 | chumikan
# Processing Record 24 of Set 7 | uruguaiana
# Processing Record 25 of Set 7 | nha trang
# Processing Record 26 of Set 7 | svetlogorsk
# Processing Record 27 of Set 7 | rundu
# Processing Record 28 of Set 7 | saint-philippe
# Processing Record 29 of Set 7 | severo-kurilsk
# Processing Record 30 of Set 7 | barra patuca
# Processing Record 31 of Set 7 | ahualulco
# Processing Record 32 of Set 7 | esperance
# Processing Record 33 of Set 7 | abu kamal
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | atar
# Processing Record 36 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 7 | uyovu
# Processing Record 38 of Set 7 | gat
# Processing Record 39 of Set 7 | vestmannaeyjar
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | gornopravdinsk
# Processing Record 42 of Set 7 | inza
# Processing Record 43 of Set 7 | athmallik
# Processing Record 44 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 7 | menongue
# Processing Record 46 of Set 7 | paamiut
# Processing Record 47 of Set 7 | yingcheng
# Processing Record 48 of Set 7 | morondava
# Processing Record 49 of Set 7 | tazmalt
# Processing Record 50 of Set 7 | longyearbyen
# Processing Record 1 of Set 8 | chardara
# Processing Record 2 of Set 8 | isiro
# Processing Record 3 of Set 8 | beringovskiy
# Processing Record 4 of Set 8 | lhokseumawe
# Processing Record 5 of Set 8 | udachnyy
# Processing Record 6 of Set 8 | eyemouth
# Processing Record 7 of Set 8 | shiloh
# Processing Record 8 of Set 8 | rincon
# Processing Record 9 of Set 8 | coruripe
# Processing Record 10 of Set 8 | yenagoa
# Processing Record 11 of Set 8 | les cayes
# Processing Record 12 of Set 8 | xining
# Processing Record 13 of Set 8 | ouadda
# Processing Record 14 of Set 8 | okhotsk
# Processing Record 15 of Set 8 | bafoulabe
# Processing Record 16 of Set 8 | klaksvik
# Processing Record 17 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 8 | selma
# Processing Record 19 of Set 8 | quatre cocos
# Processing Record 20 of Set 8 | ust-tsilma
# Processing Record 21 of Set 8 | mar del plata
# Processing Record 22 of Set 8 | champerico
# Processing Record 23 of Set 8 | harindanga
# Processing Record 24 of Set 8 | romny
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | dillon
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | talnakh
# Processing Record 29 of Set 8 | gallup
# Processing Record 30 of Set 8 | athabasca
# Processing Record 31 of Set 8 | sao miguel do araguaia
# Processing Record 32 of Set 8 | whitehorse
# Processing Record 33 of Set 8 | rio gallegos
# Processing Record 34 of Set 8 | husavik
# Processing Record 35 of Set 8 | coahuayana
# Processing Record 36 of Set 8 | knysna
# Processing Record 37 of Set 8 | souillac
# Processing Record 38 of Set 8 | mersing
# Processing Record 39 of Set 8 | makat
# Processing Record 40 of Set 8 | guanica
# Processing Record 41 of Set 8 | nome
# Processing Record 42 of Set 8 | general pico
# Processing Record 43 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 8 | nsanje
# Processing Record 45 of Set 8 | mogadishu
# Processing Record 46 of Set 8 | deputatskiy
# Processing Record 47 of Set 8 | lipin bor
# Processing Record 48 of Set 8 | margate
# Processing Record 49 of Set 8 | saldanha
# Processing Record 50 of Set 8 | araioses
# Processing Record 1 of Set 9 | naze
# Processing Record 2 of Set 9 | comodoro rivadavia
# Processing Record 3 of Set 9 | kidodi
# Processing Record 4 of Set 9 | vesyegonsk
# Processing Record 5 of Set 9 | baruun-urt
# Processing Record 6 of Set 9 | vanimo
# Processing Record 7 of Set 9 | cleburne
# Processing Record 8 of Set 9 | namibe
# Processing Record 9 of Set 9 | dembi dolo
# Processing Record 10 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 11 of Set 9 | bedesa
# Processing Record 12 of Set 9 | seoul
# Processing Record 13 of Set 9 | pangkalanbuun
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | ostersund
# Processing Record 16 of Set 9 | pak phanang
# Processing Record 17 of Set 9 | kargopol
# Processing Record 18 of Set 9 | mount isa
# Processing Record 19 of Set 9 | talakan
# Processing Record 20 of Set 9 | mount gambier
# Processing Record 21 of Set 9 | konde
# Processing Record 22 of Set 9 | tual
# Processing Record 23 of Set 9 | salisbury
# Processing Record 24 of Set 9 | shupiyan
# Processing Record 25 of Set 9 | pafos
# Processing Record 26 of Set 9 | lagos
# Processing Record 27 of Set 9 | silvania
# Processing Record 28 of Set 9 | ekhabi
# Processing Record 29 of Set 9 | tyukalinsk
# Processing Record 30 of Set 9 | port blair
# Processing Record 31 of Set 9 | bolshaya irba
# City not found. Skipping...
# Processing Record 32 of Set 9 | san francisco del mar
# Processing Record 33 of Set 9 | nkoteng
# Processing Record 34 of Set 9 | belyy yar
# Processing Record 35 of Set 9 | baiyin
# Processing Record 36 of Set 9 | maralal
# Processing Record 37 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 38 of Set 9 | bjornevatn
# Processing Record 39 of Set 9 | fare
# Processing Record 40 of Set 9 | saumur
# Processing Record 41 of Set 9 | la ronge
# Processing Record 42 of Set 9 | agadez
# Processing Record 43 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 44 of Set 9 | matagami
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | visby
# Processing Record 47 of Set 9 | richards bay
# Processing Record 48 of Set 9 | lugo
# Processing Record 49 of Set 9 | northam
# Processing Record 50 of Set 9 | dandong
# Processing Record 1 of Set 10 | hearst
# Processing Record 2 of Set 10 | kembe
# Processing Record 3 of Set 10 | ixtapa
# Processing Record 4 of Set 10 | noumea
# Processing Record 5 of Set 10 | mountain home
# Processing Record 6 of Set 10 | pravia
# Processing Record 7 of Set 10 | fort nelson
# Processing Record 8 of Set 10 | sakaiminato
# Processing Record 9 of Set 10 | boditi
# Processing Record 10 of Set 10 | sibolga
# Processing Record 11 of Set 10 | whitefish
# Processing Record 12 of Set 10 | shenjiamen
# Processing Record 13 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 10 | presidencia roque saenz pena
# Processing Record 15 of Set 10 | dali
# Processing Record 16 of Set 10 | hambantota
# Processing Record 17 of Set 10 | jos
# Processing Record 18 of Set 10 | kemijarvi
# Processing Record 19 of Set 10 | skjervoy
# Processing Record 20 of Set 10 | samandag
# Processing Record 21 of Set 10 | tiznit
# Processing Record 22 of Set 10 | san ignacio
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 25 of Set 10 | faya
# Processing Record 26 of Set 10 | leh
# Processing Record 27 of Set 10 | olafsvik
# Processing Record 28 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 10 | asino
# Processing Record 30 of Set 10 | bull savanna
# Processing Record 31 of Set 10 | vadum
# Processing Record 32 of Set 10 | rock sound
# Processing Record 33 of Set 10 | sawtell
# Processing Record 34 of Set 10 | betsiamites
# Processing Record 35 of Set 10 | kamyshevatskaya
# Processing Record 36 of Set 10 | moyo
# Processing Record 37 of Set 10 | erken-shakhar
# City not found. Skipping...
# Processing Record 38 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 39 of Set 10 | puerto escondido
# Processing Record 40 of Set 10 | almeria
# Processing Record 41 of Set 10 | bjala
# City not found. Skipping...
# Processing Record 42 of Set 10 | seia
# Processing Record 43 of Set 10 | bere
# Processing Record 44 of Set 10 | rawson
# Processing Record 45 of Set 10 | shizuishan
# Processing Record 46 of Set 10 | cabatuan
# Processing Record 47 of Set 10 | belpasso
# Processing Record 48 of Set 10 | beira
# Processing Record 49 of Set 10 | diego de almagro
# Processing Record 50 of Set 10 | bosaso
# Processing Record 1 of Set 11 | sembakung
# Processing Record 2 of Set 11 | saint-augustin
# Processing Record 3 of Set 11 | winnemucca
# Processing Record 4 of Set 11 | rocha
# Processing Record 5 of Set 11 | merauke
# Processing Record 6 of Set 11 | palmer
# Processing Record 7 of Set 11 | kota bahru
# Processing Record 8 of Set 11 | marbella
# Processing Record 9 of Set 11 | severo-yeniseyskiy
# Processing Record 10 of Set 11 | ondangwa
# Processing Record 11 of Set 11 | bentiu
# Processing Record 12 of Set 11 | cervo
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | sao miguel do tapuio
# Processing Record 15 of Set 11 | conway
# Processing Record 16 of Set 11 | songjianghe
# Processing Record 17 of Set 11 | ugoofaaru
# Processing Record 18 of Set 11 | puerto carreno
# Processing Record 19 of Set 11 | hami
# Processing Record 20 of Set 11 | alamosa
# Processing Record 21 of Set 11 | kotka
# Processing Record 22 of Set 11 | phalombe
# Processing Record 23 of Set 11 | sarangani
# Processing Record 24 of Set 11 | itabira
# Processing Record 25 of Set 11 | punta cardon
# Processing Record 26 of Set 11 | port moresby
# Processing Record 27 of Set 11 | la orilla
# Processing Record 28 of Set 11 | port said
# Processing Record 29 of Set 11 | porto novo
# Processing Record 30 of Set 11 | rylsk
# Processing Record 31 of Set 11 | aquiraz
# Processing Record 32 of Set 11 | mendota
# Processing Record 33 of Set 11 | bud
# Processing Record 34 of Set 11 | wajima
# Processing Record 35 of Set 11 | verkhoyansk
# Processing Record 36 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 11 | ligayan
# Processing Record 38 of Set 11 | novyy urgal
# Processing Record 39 of Set 11 | vila
# Processing Record 40 of Set 11 | miracatu
# Processing Record 41 of Set 11 | tagusao
# Processing Record 42 of Set 11 | kushmurun
# Processing Record 43 of Set 11 | kloulklubed
# Processing Record 44 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 11 | san nicolas
# Processing Record 46 of Set 11 | mamala
# Processing Record 47 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 11 | doctor juan leon mallorquin
# Processing Record 49 of Set 11 | kuzino
# Processing Record 50 of Set 11 | hofn
# Processing Record 1 of Set 12 | lasem
# Processing Record 2 of Set 12 | mayo
# Processing Record 3 of Set 12 | chapais
# Processing Record 4 of Set 12 | carupano
# Processing Record 5 of Set 12 | eyl
# Processing Record 6 of Set 12 | cabedelo
# Processing Record 7 of Set 12 | maragogi
# Processing Record 8 of Set 12 | cumberland
# Processing Record 9 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 12 | bocas del toro
# Processing Record 11 of Set 12 | alugan
# Processing Record 12 of Set 12 | redcliffe
# Processing Record 13 of Set 12 | rolla
# Processing Record 14 of Set 12 | tilichiki
# Processing Record 15 of Set 12 | longkou
# Processing Record 16 of Set 12 | umm lajj
# Processing Record 17 of Set 12 | sao mateus do sul
# Processing Record 18 of Set 12 | channel-port aux basques
# Processing Record 19 of Set 12 | tongliao
# Processing Record 20 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 12 | yilan
# Processing Record 22 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 12 | broken hill
# Processing Record 24 of Set 12 | linhares
# Processing Record 25 of Set 12 | kavieng
# Processing Record 26 of Set 12 | gondanglegi
# Processing Record 27 of Set 12 | half moon bay
# Processing Record 28 of Set 12 | carbonia
# Processing Record 29 of Set 12 | sidi ali
# Processing Record 30 of Set 12 | gashua
# Processing Record 31 of Set 12 | tshikapa
# Processing Record 32 of Set 12 | zhuhai
# Processing Record 33 of Set 12 | povoa de varzim
# Processing Record 34 of Set 12 | padang
# Processing Record 35 of Set 12 | tsaratanana
# Processing Record 36 of Set 12 | pavlohrad
# Processing Record 37 of Set 12 | raga
# Processing Record 38 of Set 12 | cordoba
# Processing Record 39 of Set 12 | filotion
# Processing Record 40 of Set 12 | aykino
# Processing Record 41 of Set 12 | carlsbad
# Processing Record 42 of Set 12 | pedasi
# Processing Record 43 of Set 12 | lerici
# Processing Record 44 of Set 12 | atambua
# Processing Record 45 of Set 12 | westport
# Processing Record 46 of Set 12 | yamada
# Processing Record 47 of Set 12 | takoradi
# Processing Record 48 of Set 12 | sola
# Processing Record 49 of Set 12 | santa cruz cabralia
# Processing Record 50 of Set 12 | cerritos
# Processing Record 1 of Set 13 | bogotol
# Processing Record 2 of Set 13 | constitucion
# Processing Record 3 of Set 13 | juigalpa
# Processing Record 4 of Set 13 | vryburg
# Processing Record 5 of Set 13 | riyadh
# Processing Record 6 of Set 13 | tateyama
# Processing Record 7 of Set 13 | dongying
# Processing Record 8 of Set 13 | muncar
# Processing Record 9 of Set 13 | port-gentil
# Processing Record 10 of Set 13 | verkhnyaya inta
# Processing Record 11 of Set 13 | kenai
# Processing Record 12 of Set 13 | along
# Processing Record 13 of Set 13 | vernon
# Processing Record 14 of Set 13 | gao
# Processing Record 15 of Set 13 | viedma
# Processing Record 16 of Set 13 | hohhot
# Processing Record 17 of Set 13 | mayumba
# Processing Record 18 of Set 13 | san vicente
# Processing Record 19 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 20 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 13 | werda
# Processing Record 22 of Set 13 | marzuq
# Processing Record 23 of Set 13 | kyshtovka
# Processing Record 24 of Set 13 | praia
# Processing Record 25 of Set 13 | yarmouth
# Processing Record 26 of Set 13 | bakchar
# Processing Record 27 of Set 13 | cap malheureux
# Processing Record 28 of Set 13 | alice springs
# Processing Record 29 of Set 13 | bethlehem
# Processing Record 30 of Set 13 | iquitos
# Processing Record 31 of Set 13 | idaho falls
# Processing Record 32 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 13 | tezu
# Processing Record 34 of Set 13 | kudahuvadhoo
# Processing Record 35 of Set 13 | atbasar
# Processing Record 36 of Set 13 | anadyr
# Processing Record 37 of Set 13 | monchique
# Processing Record 38 of Set 13 | natal
# Processing Record 39 of Set 13 | lakes entrance
# Processing Record 40 of Set 13 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 41 of Set 13 | kuusamo
# Processing Record 42 of Set 13 | lufilufi
# Processing Record 43 of Set 13 | kirando
# Processing Record 44 of Set 13 | mahebourg
# Processing Record 45 of Set 13 | ariquemes
# Processing Record 46 of Set 13 | stubbekobing
# Processing Record 47 of Set 13 | thiruvananthapuram
# Processing Record 48 of Set 13 | scarborough
# Processing Record 49 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 13 | sorland
# Processing Record 1 of Set 14 | lunino
# Processing Record 2 of Set 14 | ferrol
# Processing Record 3 of Set 14 | kamaishi
# Processing Record 4 of Set 14 | yumen
# Processing Record 5 of Set 14 | frontera comalapa
# Processing Record 6 of Set 14 | batagay-alyta
# Processing Record 7 of Set 14 | joensuu
# Processing Record 8 of Set 14 | yerbogachen
# Processing Record 9 of Set 14 | geraldton
# Processing Record 10 of Set 14 | vanavara
# Processing Record 11 of Set 14 | calbuco
# Processing Record 12 of Set 14 | ipixuna
# Processing Record 13 of Set 14 | makakilo city
# Processing Record 14 of Set 14 | dhidhdhoo
# Processing Record 15 of Set 14 | tupik
# Processing Record 16 of Set 14 | quang ngai
# Processing Record 17 of Set 14 | lavrentiya
# Processing Record 18 of Set 14 | pankrushikha
# Processing Record 19 of Set 14 | manzanillo
# Processing Record 20 of Set 14 | ife
# Processing Record 21 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 14 | kalmunai
# Processing Record 23 of Set 14 | kitimat
# Processing Record 24 of Set 14 | sabzevar
# Processing Record 25 of Set 14 | yelizovo
# Processing Record 26 of Set 14 | faridpur
# Processing Record 27 of Set 14 | olga
# Processing Record 28 of Set 14 | biltine
# Processing Record 29 of Set 14 | moose factory
# Processing Record 30 of Set 14 | linjiang
# Processing Record 31 of Set 14 | najran
# Processing Record 32 of Set 14 | dauriya
# Processing Record 33 of Set 14 | skibbereen
# Processing Record 34 of Set 14 | sheridan
# Processing Record 35 of Set 14 | bagdarin
# Processing Record 36 of Set 14 | maldonado
# Processing Record 37 of Set 14 | ketchikan
# Processing Record 38 of Set 14 | kuito
# Processing Record 39 of Set 14 | praya
# Processing Record 40 of Set 14 | parrita
# Processing Record 41 of Set 14 | mayor pablo lagerenza
# Processing Record 42 of Set 14 | kyabe
# Processing Record 43 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 14 | mbeya
# Processing Record 45 of Set 14 | kpalime
# Processing Record 46 of Set 14 | qasigiannguit
# Processing Record 47 of Set 14 | nambucca heads
# Processing Record 48 of Set 14 | colwyn bay
# Processing Record 49 of Set 14 | neiafu
# Processing Record 50 of Set 14 | bonavista
# Processing Record 1 of Set 15 | kirovskiy
# Processing Record 2 of Set 15 | tvedestrand
# Processing Record 3 of Set 15 | shenzhen
# Processing Record 4 of Set 15 | lieksa
# Processing Record 5 of Set 15 | chicama
# Processing Record 6 of Set 15 | diplo
# Processing Record 7 of Set 15 | izhma
# Processing Record 8 of Set 15 | diffa
# Processing Record 9 of Set 15 | coihaique
# Processing Record 10 of Set 15 | inirida
# Processing Record 11 of Set 15 | anloga
# Processing Record 12 of Set 15 | mingaora
# Processing Record 13 of Set 15 | middelburg
# Processing Record 14 of Set 15 | srednekolymsk
# Processing Record 15 of Set 15 | mangaratiba
# Processing Record 16 of Set 15 | guadalupe y calvo
# Processing Record 17 of Set 15 | sandwick
# Processing Record 18 of Set 15 | troy
# Processing Record 19 of Set 15 | iranshahr
# Processing Record 20 of Set 15 | camopi
# Processing Record 21 of Set 15 | mackenzie
# Processing Record 22 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 23 of Set 15 | mooi river
# City not found. Skipping...
# Processing Record 24 of Set 15 | kholm-zhirkovskiy
# Processing Record 25 of Set 15 | vilyuysk
# Processing Record 26 of Set 15 | beyneu
# Processing Record 27 of Set 15 | bandiagara
# Processing Record 28 of Set 15 | siilinjarvi
# Processing Record 29 of Set 15 | bonoua
# Processing Record 30 of Set 15 | auch
# Processing Record 31 of Set 15 | guebwiller
# Processing Record 32 of Set 15 | namtsy
# Processing Record 33 of Set 15 | ongandjera
# Processing Record 34 of Set 15 | sistranda
# Processing Record 35 of Set 15 | kholodnyy
# Processing Record 36 of Set 15 | tevaitoa
# Processing Record 37 of Set 15 | bukachacha
# Processing Record 38 of Set 15 | ust-omchug
# Processing Record 39 of Set 15 | bedele
# Processing Record 40 of Set 15 | hinton
# Processing Record 41 of Set 15 | kulhudhuffushi
# Processing Record 42 of Set 15 | lipari
# Processing Record 43 of Set 15 | sur
# Processing Record 44 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 45 of Set 15 | sabang
# Processing Record 46 of Set 15 | perth
# Processing Record 47 of Set 15 | tromso
# Processing Record 48 of Set 15 | khushab
# Processing Record 49 of Set 15 | pareora
# Processing Record 50 of Set 15 | palauig
# Processing Record 1 of Set 16 | lima
# Processing Record 2 of Set 16 | bahia blanca
# Processing Record 3 of Set 16 | kemise
# Processing Record 4 of Set 16 | kiama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bad Liebenwerda      DE  51.5167   13.4000     42.80        75          20
# 1           Atuona      PF  -9.8000 -139.0333     80.29        79          30
# 2       Walvis Bay      NA -22.9575   14.5053     64.00        72           6
# 3           Bethel      US  41.3712  -73.4140     61.00        20           1
# 4         Mabaruma      GY   8.2000  -59.7833     75.63        90         100
# 5         Thompson      CA  55.7435  -97.8558     24.80        74          90
# 6          Rikitea      PF -23.1203 -134.9692     79.11        68         100
# 7       Kaitangata      NZ -46.2817  169.8464     53.01        79          22
# 8           Laguna      US  38.4210 -121.4238     75.00        43           1
# 9            Pevek      RU  69.7008  170.3133     12.76        89          48
#
#    Wind Speed Current Description
# 0        2.30          few clouds
# 1       22.82    scattered clouds
# 2        8.05           clear sky
# 3       14.97           clear sky
# 4        4.88     overcast clouds
# 5       13.80          light snow
# 6       17.56     overcast clouds
# 7        5.99          few clouds
# 8       12.66           clear sky
# 9        3.58    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

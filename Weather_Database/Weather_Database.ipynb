# %%
# %load_ext autoreload

# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.00, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_country = city_weather["sys"]["country"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | mudon
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | ulladulla
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | knysna
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | vila franca do campo
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | mecca
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | sergeyevka
# Processing Record 25 of Set 1 | puerto suarez
# Processing Record 26 of Set 1 | tangkak
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | bud
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | puerto leguizamo
# Processing Record 31 of Set 1 | lisakovsk
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | biggar
# Processing Record 34 of Set 1 | gubkinskiy
# Processing Record 35 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | aklavik
# Processing Record 39 of Set 1 | inhambane
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | kloulklubed
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | kavieng
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | nelson bay
# Processing Record 50 of Set 1 | korla
# Processing Record 1 of Set 2 | broome
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | okato
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | saryg-sep
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | zyryanka
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 2 | luwuk
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | tonstad
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | karasjok
# Processing Record 23 of Set 2 | matagami
# Processing Record 24 of Set 2 | hervey bay
# Processing Record 25 of Set 2 | coruripe
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | vastervik
# City not found. Skipping...
# Processing Record 28 of Set 2 | soyo
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | rodeo
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 2 | touros
# Processing Record 35 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 2 | hovd
# Processing Record 37 of Set 2 | ribeira brava
# Processing Record 38 of Set 2 | guaruja
# Processing Record 39 of Set 2 | husavik
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | la asuncion
# Processing Record 42 of Set 2 | olupona
# Processing Record 43 of Set 2 | luziania
# Processing Record 44 of Set 2 | summerside
# Processing Record 45 of Set 2 | craig
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | ibra
# Processing Record 49 of Set 2 | diu
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | jacobabad
# Processing Record 2 of Set 3 | aksha
# Processing Record 3 of Set 3 | bluff
# Processing Record 4 of Set 3 | barra patuca
# Processing Record 5 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | srednekolymsk
# Processing Record 8 of Set 3 | puri
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | miquelon
# Processing Record 11 of Set 3 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 12 of Set 3 | rize
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | suozhen
# Processing Record 16 of Set 3 | sorland
# Processing Record 17 of Set 3 | hemnesberget
# Processing Record 18 of Set 3 | amapa
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | deputatskiy
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | vila do maio
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | hashtrud
# Processing Record 29 of Set 3 | swan hill
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | ous
# Processing Record 32 of Set 3 | emerald
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | puerto escondido
# Processing Record 35 of Set 3 | buchanan
# Processing Record 36 of Set 3 | mokokchung
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | buin
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | camanducaia
# Processing Record 41 of Set 3 | asau
# Processing Record 42 of Set 3 | oriximina
# Processing Record 43 of Set 3 | ribeira grande
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | inuvik
# Processing Record 46 of Set 3 | axim
# Processing Record 47 of Set 3 | santa fe do sul
# Processing Record 48 of Set 3 | beirut
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | farah
# Processing Record 1 of Set 4 | chicama
# Processing Record 2 of Set 4 | kaniama
# Processing Record 3 of Set 4 | herat
# Processing Record 4 of Set 4 | coahuayana
# Processing Record 5 of Set 4 | taltal
# Processing Record 6 of Set 4 | butaritari
# Processing Record 7 of Set 4 | namibe
# Processing Record 8 of Set 4 | boca do acre
# Processing Record 9 of Set 4 | san cristobal
# Processing Record 10 of Set 4 | aykhal
# Processing Record 11 of Set 4 | elizabeth city
# Processing Record 12 of Set 4 | seoul
# Processing Record 13 of Set 4 | curaca
# Processing Record 14 of Set 4 | perth
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | makakilo city
# Processing Record 18 of Set 4 | iskilip
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | moyale
# Processing Record 22 of Set 4 | along
# Processing Record 23 of Set 4 | kavaratti
# Processing Record 24 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 4 | bulalacao
# Processing Record 26 of Set 4 | pisco
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | lamu
# Processing Record 29 of Set 4 | gweru
# Processing Record 30 of Set 4 | alice springs
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | sangar
# Processing Record 34 of Set 4 | port hardy
# Processing Record 35 of Set 4 | jardim
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | lumphat
# Processing Record 38 of Set 4 | pribyslav
# Processing Record 39 of Set 4 | pemba
# Processing Record 40 of Set 4 | aboso
# Processing Record 41 of Set 4 | namuac
# Processing Record 42 of Set 4 | shelburne
# Processing Record 43 of Set 4 | tilichiki
# Processing Record 44 of Set 4 | mankera
# Processing Record 45 of Set 4 | westport
# Processing Record 46 of Set 4 | pauini
# Processing Record 47 of Set 4 | svetlogorsk
# Processing Record 48 of Set 4 | coquimbo
# Processing Record 49 of Set 4 | carutapera
# Processing Record 50 of Set 4 | bad doberan
# Processing Record 1 of Set 5 | raudeberg
# Processing Record 2 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 5 | isangel
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | shitanjing
# Processing Record 7 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | marmande
# Processing Record 10 of Set 5 | nichinan
# Processing Record 11 of Set 5 | viru
# Processing Record 12 of Set 5 | los llanos de aridane
# Processing Record 13 of Set 5 | dharchula
# Processing Record 14 of Set 5 | tuktoyaktuk
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | aksarka
# Processing Record 17 of Set 5 | margate
# Processing Record 18 of Set 5 | kokopo
# Processing Record 19 of Set 5 | huanren
# Processing Record 20 of Set 5 | mayo
# Processing Record 21 of Set 5 | bokoro
# Processing Record 22 of Set 5 | smithers
# Processing Record 23 of Set 5 | rocha
# Processing Record 24 of Set 5 | la ronge
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | ayagoz
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | ahipara
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 5 | alindao
# Processing Record 35 of Set 5 | salekhard
# Processing Record 36 of Set 5 | ermoupolis
# Processing Record 37 of Set 5 | upata
# Processing Record 38 of Set 5 | taoudenni
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | shingu
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | wattegama
# Processing Record 43 of Set 5 | de-kastri
# Processing Record 44 of Set 5 | surt
# Processing Record 45 of Set 5 | kutum
# Processing Record 46 of Set 5 | agadez
# Processing Record 47 of Set 5 | datong
# Processing Record 48 of Set 5 | maldonado
# Processing Record 49 of Set 5 | kasane
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | jinka
# Processing Record 2 of Set 6 | rio gallegos
# Processing Record 3 of Set 6 | harboore
# Processing Record 4 of Set 6 | burica
# City not found. Skipping...
# Processing Record 5 of Set 6 | genc
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | yelovo
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | bontang
# Processing Record 10 of Set 6 | mabaruma
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | fortuna
# Processing Record 13 of Set 6 | thoen
# Processing Record 14 of Set 6 | tyukalinsk
# Processing Record 15 of Set 6 | manicore
# Processing Record 16 of Set 6 | buta
# Processing Record 17 of Set 6 | zhigansk
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | mahebourg
# Processing Record 21 of Set 6 | gao
# Processing Record 22 of Set 6 | mezen
# Processing Record 23 of Set 6 | nueva loja
# Processing Record 24 of Set 6 | kurtamysh
# Processing Record 25 of Set 6 | la seyne-sur-mer
# Processing Record 26 of Set 6 | pringsewu
# Processing Record 27 of Set 6 | ouallam
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | yanaul
# Processing Record 31 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 6 | guilin
# Processing Record 33 of Set 6 | sisimiut
# Processing Record 34 of Set 6 | tura
# Processing Record 35 of Set 6 | mata
# Processing Record 36 of Set 6 | bukama
# Processing Record 37 of Set 6 | cradock
# Processing Record 38 of Set 6 | half moon bay
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | arraial do cabo
# Processing Record 42 of Set 6 | jiwani
# Processing Record 43 of Set 6 | hyeres
# Processing Record 44 of Set 6 | qurayyat
# Processing Record 45 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 46 of Set 6 | pokosnoye
# Processing Record 47 of Set 6 | pitimbu
# Processing Record 48 of Set 6 | tsevie
# Processing Record 49 of Set 6 | naze
# Processing Record 50 of Set 6 | neuquen
# Processing Record 1 of Set 7 | vardo
# Processing Record 2 of Set 7 | kalmunai
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | mount darwin
# Processing Record 5 of Set 7 | kijang
# Processing Record 6 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 7 of Set 7 | ola
# Processing Record 8 of Set 7 | mount isa
# Processing Record 9 of Set 7 | provideniya
# Processing Record 10 of Set 7 | la palma
# Processing Record 11 of Set 7 | poum
# Processing Record 12 of Set 7 | bundaberg
# Processing Record 13 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 7 | ismailia
# Processing Record 15 of Set 7 | chapais
# Processing Record 16 of Set 7 | faya
# Processing Record 17 of Set 7 | wad rawah
# Processing Record 18 of Set 7 | mount hagen
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | lichinga
# Processing Record 21 of Set 7 | richards bay
# Processing Record 22 of Set 7 | tolaga bay
# Processing Record 23 of Set 7 | pundaguitan
# Processing Record 24 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 7 | yandoon
# City not found. Skipping...
# Processing Record 26 of Set 7 | ust-nera
# Processing Record 27 of Set 7 | xuanhua
# Processing Record 28 of Set 7 | north bend
# Processing Record 29 of Set 7 | nanortalik
# Processing Record 30 of Set 7 | zhangjiakou
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | parintins
# Processing Record 33 of Set 7 | male
# Processing Record 34 of Set 7 | kibala
# Processing Record 35 of Set 7 | san nicola
# Processing Record 36 of Set 7 | gorontalo
# Processing Record 37 of Set 7 | piacabucu
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | peniche
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | pak phanang
# Processing Record 42 of Set 7 | sedro-woolley
# Processing Record 43 of Set 7 | ambilobe
# Processing Record 44 of Set 7 | porto novo
# Processing Record 45 of Set 7 | nuevo casas grandes
# Processing Record 46 of Set 7 | riyadh
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | kahului
# Processing Record 49 of Set 7 | uniao da victoria
# City not found. Skipping...
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | tornio
# Processing Record 2 of Set 8 | kedrovyy
# Processing Record 3 of Set 8 | honggang
# Processing Record 4 of Set 8 | shieli
# Processing Record 5 of Set 8 | waipawa
# Processing Record 6 of Set 8 | tourlaville
# Processing Record 7 of Set 8 | tomatlan
# Processing Record 8 of Set 8 | boueni
# Processing Record 9 of Set 8 | zabrani
# Processing Record 10 of Set 8 | sobolevo
# Processing Record 11 of Set 8 | port hedland
# Processing Record 12 of Set 8 | san andres
# Processing Record 13 of Set 8 | quang ngai
# Processing Record 14 of Set 8 | martapura
# Processing Record 15 of Set 8 | malinovoye ozero
# Processing Record 16 of Set 8 | dingzhou
# Processing Record 17 of Set 8 | kon tum
# Processing Record 18 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 8 | altamont
# Processing Record 20 of Set 8 | kurilsk
# Processing Record 21 of Set 8 | zhezkazgan
# Processing Record 22 of Set 8 | baiquan
# Processing Record 23 of Set 8 | impfondo
# Processing Record 24 of Set 8 | cabedelo
# Processing Record 25 of Set 8 | koupela
# Processing Record 26 of Set 8 | belyy yar
# Processing Record 27 of Set 8 | evansville
# Processing Record 28 of Set 8 | nyurba
# Processing Record 29 of Set 8 | andilamena
# Processing Record 30 of Set 8 | lindome
# Processing Record 31 of Set 8 | samarai
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | roma
# Processing Record 34 of Set 8 | maroantsetra
# Processing Record 35 of Set 8 | jurado
# Processing Record 36 of Set 8 | yerbogachen
# Processing Record 37 of Set 8 | ondangwa
# Processing Record 38 of Set 8 | shache
# Processing Record 39 of Set 8 | takoradi
# Processing Record 40 of Set 8 | ayan
# Processing Record 41 of Set 8 | haimen
# Processing Record 42 of Set 8 | flin flon
# Processing Record 43 of Set 8 | loa janan
# Processing Record 44 of Set 8 | minab
# Processing Record 45 of Set 8 | hirara
# Processing Record 46 of Set 8 | trinidad
# Processing Record 47 of Set 8 | puerto del rosario
# Processing Record 48 of Set 8 | dorado
# Processing Record 49 of Set 8 | lompoc
# Processing Record 50 of Set 8 | cap malheureux
# Processing Record 1 of Set 9 | tiznit
# Processing Record 2 of Set 9 | paamiut
# Processing Record 3 of Set 9 | kedarnath
# City not found. Skipping...
# Processing Record 4 of Set 9 | biak
# Processing Record 5 of Set 9 | sayat
# Processing Record 6 of Set 9 | matara
# Processing Record 7 of Set 9 | troitskoye
# Processing Record 8 of Set 9 | andenes
# Processing Record 9 of Set 9 | kaeo
# Processing Record 10 of Set 9 | hambantota
# Processing Record 11 of Set 9 | muravlenko
# Processing Record 12 of Set 9 | sao filipe
# Processing Record 13 of Set 9 | kodiak
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | broken hill
# Processing Record 16 of Set 9 | luckenwalde
# Processing Record 17 of Set 9 | zhaotong
# Processing Record 18 of Set 9 | sao felix do xingu
# Processing Record 19 of Set 9 | anadyr
# Processing Record 20 of Set 9 | keti bandar
# Processing Record 21 of Set 9 | sterling
# Processing Record 22 of Set 9 | todos santos
# Processing Record 23 of Set 9 | guerrero negro
# Processing Record 24 of Set 9 | karratha
# Processing Record 25 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 9 | sorkjosen
# Processing Record 27 of Set 9 | san luis
# Processing Record 28 of Set 9 | gizo
# Processing Record 29 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 30 of Set 9 | darovskoy
# Processing Record 31 of Set 9 | domoni
# Processing Record 32 of Set 9 | tazovskiy
# Processing Record 33 of Set 9 | takayama
# Processing Record 34 of Set 9 | corrales
# Processing Record 35 of Set 9 | tual
# Processing Record 36 of Set 9 | avera
# Processing Record 37 of Set 9 | constitucion
# Processing Record 38 of Set 9 | klyuchi
# Processing Record 39 of Set 9 | tasiilaq
# Processing Record 40 of Set 9 | muroto
# Processing Record 41 of Set 9 | petatlan
# Processing Record 42 of Set 9 | lucapa
# Processing Record 43 of Set 9 | ati
# Processing Record 44 of Set 9 | severomuysk
# Processing Record 45 of Set 9 | erzin
# Processing Record 46 of Set 9 | cidreira
# Processing Record 47 of Set 9 | kirakira
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | tamandare
# Processing Record 50 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 1 of Set 10 | ankazoabo
# Processing Record 2 of Set 10 | paraiso
# Processing Record 3 of Set 10 | vestmannaeyjar
# Processing Record 4 of Set 10 | mount pleasant
# Processing Record 5 of Set 10 | ibipeba
# Processing Record 6 of Set 10 | gazanjyk
# Processing Record 7 of Set 10 | manggar
# Processing Record 8 of Set 10 | kushima
# Processing Record 9 of Set 10 | montepuez
# Processing Record 10 of Set 10 | camacha
# Processing Record 11 of Set 10 | viedma
# Processing Record 12 of Set 10 | usinsk
# Processing Record 13 of Set 10 | tuy hoa
# Processing Record 14 of Set 10 | toila
# Processing Record 15 of Set 10 | oussouye
# Processing Record 16 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 17 of Set 10 | kazanskaya
# Processing Record 18 of Set 10 | mitsamiouli
# Processing Record 19 of Set 10 | hay river
# Processing Record 20 of Set 10 | pomabamba
# Processing Record 21 of Set 10 | cherlak
# Processing Record 22 of Set 10 | gold coast
# Processing Record 23 of Set 10 | mareeba
# Processing Record 24 of Set 10 | kimbe
# Processing Record 25 of Set 10 | whitehorse
# Processing Record 26 of Set 10 | basco
# Processing Record 27 of Set 10 | suratgarh
# Processing Record 28 of Set 10 | saint-augustin
# Processing Record 29 of Set 10 | grindavik
# Processing Record 30 of Set 10 | bosaso
# Processing Record 31 of Set 10 | henties bay
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 10 | perustica
# City not found. Skipping...
# Processing Record 35 of Set 10 | lhokseumawe
# Processing Record 36 of Set 10 | nioro
# Processing Record 37 of Set 10 | mansa
# Processing Record 38 of Set 10 | megion
# Processing Record 39 of Set 10 | okha
# Processing Record 40 of Set 10 | alpena
# Processing Record 41 of Set 10 | edd
# Processing Record 42 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 10 | ancud
# Processing Record 44 of Set 10 | aran
# Processing Record 45 of Set 10 | omsukchan
# Processing Record 46 of Set 10 | beringovskiy
# Processing Record 47 of Set 10 | port lincoln
# Processing Record 48 of Set 10 | zaritap
# Processing Record 49 of Set 10 | grandview
# Processing Record 50 of Set 10 | morehead
# Processing Record 1 of Set 11 | birao
# Processing Record 2 of Set 11 | pineville
# Processing Record 3 of Set 11 | jaciara
# Processing Record 4 of Set 11 | vao
# Processing Record 5 of Set 11 | yichang
# Processing Record 6 of Set 11 | coihaique
# Processing Record 7 of Set 11 | lorengau
# Processing Record 8 of Set 11 | santiago de cao
# Processing Record 9 of Set 11 | taga
# Processing Record 10 of Set 11 | nyanguge
# Processing Record 11 of Set 11 | santiago del estero
# Processing Record 12 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 11 | nim ka thana
# City not found. Skipping...
# Processing Record 14 of Set 11 | kununurra
# Processing Record 15 of Set 11 | linqiong
# Processing Record 16 of Set 11 | mazatan
# Processing Record 17 of Set 11 | navabad
# City not found. Skipping...
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | chara
# Processing Record 20 of Set 11 | havoysund
# Processing Record 21 of Set 11 | nenjiang
# Processing Record 22 of Set 11 | jumla
# Processing Record 23 of Set 11 | zhangye
# Processing Record 24 of Set 11 | kindia
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | hami
# Processing Record 27 of Set 11 | walvis bay
# Processing Record 28 of Set 11 | hailar
# Processing Record 29 of Set 11 | nome
# Processing Record 30 of Set 11 | imeni morozova
# Processing Record 31 of Set 11 | chilia veche
# Processing Record 32 of Set 11 | lata
# Processing Record 33 of Set 11 | honningsvag
# Processing Record 34 of Set 11 | ejido
# Processing Record 35 of Set 11 | eureka
# Processing Record 36 of Set 11 | iranshahr
# Processing Record 37 of Set 11 | atasu
# Processing Record 38 of Set 11 | hellin
# Processing Record 39 of Set 11 | kyaikkami
# Processing Record 40 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 11 | grand gaube
# Processing Record 42 of Set 11 | haines junction
# Processing Record 43 of Set 11 | vila velha
# Processing Record 44 of Set 11 | yumen
# Processing Record 45 of Set 11 | awbari
# Processing Record 46 of Set 11 | mga
# Processing Record 47 of Set 11 | turukhansk
# Processing Record 48 of Set 11 | novoagansk
# Processing Record 49 of Set 11 | geelong
# Processing Record 50 of Set 11 | dakar
# Processing Record 1 of Set 12 | napasar
# Processing Record 2 of Set 12 | bilma
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | athabasca
# Processing Record 5 of Set 12 | olafsvik
# Processing Record 6 of Set 12 | saint-georges
# Processing Record 7 of Set 12 | manoel urbano
# Processing Record 8 of Set 12 | aseri
# Processing Record 9 of Set 12 | celestun
# Processing Record 10 of Set 12 | marawi
# Processing Record 11 of Set 12 | cayenne
# Processing Record 12 of Set 12 | batemans bay
# Processing Record 13 of Set 12 | gujranwala
# Processing Record 14 of Set 12 | galle
# Processing Record 15 of Set 12 | rauma
# Processing Record 16 of Set 12 | banjar
# Processing Record 17 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 12 | darhan
# Processing Record 19 of Set 12 | adrian
# Processing Record 20 of Set 12 | nhulunbuy
# Processing Record 21 of Set 12 | montana
# Processing Record 22 of Set 12 | flinders
# Processing Record 23 of Set 12 | bilibino
# Processing Record 24 of Set 12 | el cobre
# Processing Record 25 of Set 12 | colares
# Processing Record 26 of Set 12 | salta
# Processing Record 27 of Set 12 | tulsipur
# Processing Record 28 of Set 12 | mukhen
# Processing Record 29 of Set 12 | mahibadhoo
# Processing Record 30 of Set 12 | tubuala
# Processing Record 31 of Set 12 | bonthe
# Processing Record 32 of Set 12 | clarence town
# Processing Record 33 of Set 12 | cururupu
# Processing Record 34 of Set 12 | gaoual
# Processing Record 35 of Set 12 | macau
# Processing Record 36 of Set 12 | wembley
# Processing Record 37 of Set 12 | hope
# Processing Record 38 of Set 12 | prince rupert
# Processing Record 39 of Set 12 | mandalgovi
# Processing Record 40 of Set 12 | zhukovskiy
# Processing Record 41 of Set 12 | ilebo
# Processing Record 42 of Set 12 | jadu
# Processing Record 43 of Set 12 | bronnoysund
# Processing Record 44 of Set 12 | linjiang
# Processing Record 45 of Set 12 | beira
# Processing Record 46 of Set 12 | kozluk
# Processing Record 47 of Set 12 | anamur
# Processing Record 48 of Set 12 | ekhabi
# Processing Record 49 of Set 12 | luanda
# Processing Record 50 of Set 12 | katobu
# Processing Record 1 of Set 13 | rolla
# Processing Record 2 of Set 13 | havre-saint-pierre
# Processing Record 3 of Set 13 | porto nacional
# Processing Record 4 of Set 13 | nicolas bravo
# Processing Record 5 of Set 13 | amalapuram
# Processing Record 6 of Set 13 | pangkalanbuun
# Processing Record 7 of Set 13 | hokitika
# Processing Record 8 of Set 13 | kouroussa
# Processing Record 9 of Set 13 | kenitra
# Processing Record 10 of Set 13 | murashi
# Processing Record 11 of Set 13 | khani
# Processing Record 12 of Set 13 | saucillo
# Processing Record 13 of Set 13 | verkh-chebula
# Processing Record 14 of Set 13 | mino
# Processing Record 15 of Set 13 | sinjhoro
# Processing Record 16 of Set 13 | masindi
# Processing Record 17 of Set 13 | termiz
# Processing Record 18 of Set 13 | namikupa
# Processing Record 19 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 13 | shimoda
# Processing Record 21 of Set 13 | noshiro
# Processing Record 22 of Set 13 | champerico
# Processing Record 23 of Set 13 | kuah
# Processing Record 24 of Set 13 | ketchikan
# Processing Record 25 of Set 13 | general pico
# Processing Record 26 of Set 13 | kieta
# Processing Record 27 of Set 13 | crossville
# Processing Record 28 of Set 13 | auki
# Processing Record 29 of Set 13 | sabha
# Processing Record 30 of Set 13 | aranos
# Processing Record 31 of Set 13 | wainwright
# Processing Record 32 of Set 13 | telsiai
# Processing Record 33 of Set 13 | thabazimbi
# Processing Record 34 of Set 13 | beian
# Processing Record 35 of Set 13 | bonavista
# Processing Record 36 of Set 13 | srikakulam
# Processing Record 37 of Set 13 | tobermory
# Processing Record 38 of Set 13 | severnoye
# Processing Record 39 of Set 13 | russell
# Processing Record 40 of Set 13 | roebourne
# Processing Record 41 of Set 13 | yeppoon
# Processing Record 42 of Set 13 | loreto
# Processing Record 43 of Set 13 | atambua
# Processing Record 44 of Set 13 | narsaq
# Processing Record 45 of Set 13 | novo aripuana
# Processing Record 46 of Set 13 | monchegorsk
# Processing Record 47 of Set 13 | rio grande
# Processing Record 48 of Set 13 | erenhot
# Processing Record 49 of Set 13 | verkhoyansk
# Processing Record 50 of Set 13 | carmen
# Processing Record 1 of Set 14 | ulaanbaatar
# Processing Record 2 of Set 14 | slavutych
# Processing Record 3 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 4 of Set 14 | blackwater
# Processing Record 5 of Set 14 | velizh
# Processing Record 6 of Set 14 | san angelo
# Processing Record 7 of Set 14 | maragogi
# Processing Record 8 of Set 14 | dukat
# Processing Record 9 of Set 14 | palana
# Processing Record 10 of Set 14 | nantucket
# Processing Record 11 of Set 14 | clinton
# Processing Record 12 of Set 14 | praxedis guerrero
# Processing Record 13 of Set 14 | angra dos reis
# Processing Record 14 of Set 14 | wasilla
# Processing Record 15 of Set 14 | antofagasta
# Processing Record 16 of Set 14 | guadalupe y calvo
# Processing Record 17 of Set 14 | dera bugti
# Processing Record 18 of Set 14 | odessa
# Processing Record 19 of Set 14 | leh
# Processing Record 20 of Set 14 | asmara
# Processing Record 21 of Set 14 | sovetskaya gavan
# Processing Record 22 of Set 14 | guaymas
# Processing Record 23 of Set 14 | fochville
# Processing Record 24 of Set 14 | betki
# City not found. Skipping...
# Processing Record 25 of Set 14 | williston
# Processing Record 26 of Set 14 | muret
# Processing Record 27 of Set 14 | peachtree city
# Processing Record 28 of Set 14 | morondava
# Processing Record 29 of Set 14 | nueva helvecia
# Processing Record 30 of Set 14 | honiara
# Processing Record 31 of Set 14 | les escoumins
# Processing Record 32 of Set 14 | bustamante
# Processing Record 33 of Set 14 | maun
# Processing Record 34 of Set 14 | sinnamary
# Processing Record 35 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 14 | alamosa
# Processing Record 37 of Set 14 | carbonia
# Processing Record 38 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 39 of Set 14 | malakal
# Processing Record 40 of Set 14 | ternate
# Processing Record 41 of Set 14 | lagunillas
# Processing Record 42 of Set 14 | bereda
# Processing Record 43 of Set 14 | uzhur
# Processing Record 44 of Set 14 | arica
# Processing Record 45 of Set 14 | itoman
# Processing Record 46 of Set 14 | payson
# Processing Record 47 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 14 | kathu
# Processing Record 49 of Set 14 | azare
# Processing Record 50 of Set 14 | chandvad
# Processing Record 1 of Set 15 | butembo
# Processing Record 2 of Set 15 | arandis
# Processing Record 3 of Set 15 | ocampo
# Processing Record 4 of Set 15 | nemuro
# Processing Record 5 of Set 15 | pemangkat
# Processing Record 6 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 15 | pangody
# Processing Record 8 of Set 15 | mitu
# Processing Record 9 of Set 15 | zimmi
# Processing Record 10 of Set 15 | pipar
# Processing Record 11 of Set 15 | shcholkine
# City not found. Skipping...
# Processing Record 12 of Set 15 | talara
# Processing Record 13 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 15 | melito di porto salvo
# Processing Record 15 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 15 | patacamaya
# Processing Record 17 of Set 15 | banfora
# Processing Record 18 of Set 15 | stornoway
# Processing Record 19 of Set 15 | amga
# Processing Record 20 of Set 15 | kuito
# Processing Record 21 of Set 15 | sao manuel
# Processing Record 22 of Set 15 | tessalit
# Processing Record 23 of Set 15 | tumba
# Processing Record 24 of Set 15 | salinopolis
# Processing Record 25 of Set 15 | diego de almagro
# Processing Record 26 of Set 15 | mwingi
# Processing Record 27 of Set 15 | mongo
# Processing Record 28 of Set 15 | olavarria
# Processing Record 29 of Set 15 | vilhena
# Processing Record 30 of Set 15 | saint anthony
# Processing Record 31 of Set 15 | trat
# Processing Record 32 of Set 15 | pucallpa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hobart      AU -42.8794  147.3294     51.80        58          75
# 1      Avarua      CK -21.2078 -159.7750     75.20        94          75
# 2      Albany      US  42.6001  -73.9662     41.00        34         100
# 3     Ushuaia      AR -54.8000  -68.3000     44.60        87          75
# 4      Barrow      US  71.2906 -156.7887     19.40        73           1
# 5       Mudon      MM  16.2578   97.7164     80.67        79          65
# 6   Cape Town      ZA -33.9258   18.4232     64.00        88           0
# 7  Georgetown      MY   5.4112  100.3354     77.00        94          40
# 8       Kapaa      US  22.0752 -159.3190     78.01        83          40
# 9   Ulladulla      AU -35.3500  150.4667     51.80        62           0
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1       19.57          light rain
# 2        3.00     overcast clouds
# 3        5.75       broken clouds
# 4        6.91           clear sky
# 5        4.56       broken clouds
# 6        9.22           clear sky
# 7        1.14    scattered clouds
# 8        9.22    scattered clouds
# 9       10.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
